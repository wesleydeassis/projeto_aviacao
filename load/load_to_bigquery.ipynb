# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account
from pandas_gbq import to_gbq

# %%
# carregando as credenciais
credencial = service_account.Credentials.from_service_account_file(
  r'C:\seu caminho.json',
  scopes=["https://www.googleapis.com/auth/bigquery"],
)

# %%
df = pd.read_excel(r"C:seucaminho\analise_aviacao\aeronaves_ocorrencias.xlsx")
df.head()
# Out:
#   ocorrencia_dia  codigo_ocorrencia2 ocorrencia_uf ocorrencia_classificacao  \
# 0     11/05/2025               87125            CE                INCIDENTE
# 1     08/05/2025               87124            MG                INCIDENTE
# 2     09/05/2025               87123            SP                INCIDENTE
# 3     04/05/2025               87122            RS                INCIDENTE
# 4     10/05/2025               87121            SP                INCIDENTE
#
#   aeronave_matricula                      aeronave_voo_origem  \
# 0              PSAEX                                VIRACOPOS
# 1              PRYXD  TENENTE-CORONEL AVIADOR CÉSAR BOMBONATO
# 2              PRXBT          GOVERNADOR ANDRÉ FRANCO MONTORO
# 3              PRAKJ                              SANTA MARIA
# 4              PRMHK          PROFESSOR ERIBERTO MANOEL REINO
#
#               aeronave_voo_destino aeronave_tipo_operacao  \
# 0       ORLANDO BEZERRA DE MENEZES                REGULAR
# ...

# %%
#enviar dataframe para o bigquery
df.to_gbq(destination_table='*********.tb_aeronaves_ocorrencias',
          project_id='************',
          if_exists='replace',
          credentials=credencial)

#replace = subistuir a antiga pela original 
#append = adiciona dados no fim da tabela
# Out:
# C:\Users\ADM\AppData\Local\Temp\ipykernel_10924\1972637234.py:2: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   df.to_gbq(destination_table='pythoncurso-472318.AulaPython.tb_aeronaves_ocorrencias',
# 100%|██████████| 1/1 [00:00<?, ?it/s]
